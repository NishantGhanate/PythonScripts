# %%
# https://graphviz.readthedocs.io/en/stable/manual.html

# %%
from graphviz import Digraph
import os     

os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'

# %%
g = Digraph('G', filename='helloWorld.gv') # ,format="png" deafult is PDF

g.edge('Hello', 'World')

g #g.view()

# %%
ps = Digraph(name='pet-shop', node_attr={'shape': 'plaintext'})
ps.node('HigherLanguage')
ps.node('AssemblyLangauge')
ps.edge('HigherLanguage', 'AssemblyLangauge')
ps.graph_attr['rankdir'] = 'LR'
ps.edge_attr.update(arrowhead='vee', arrowsize='2')
print(ps.source)  
ps
# Out:
# digraph "pet-shop" {
# 	graph [rankdir=LR]
# 	node [shape=plaintext]
# 	edge [arrowhead=vee arrowsize=2]
# 	HigherLanguage
# 	AssemblyLangauge
# 	HigherLanguage -> AssemblyLangauge
# }
